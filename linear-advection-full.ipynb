# %% [markdown]
# # Spectral Methods for Linear Advection

# %% [markdown]
# As an extremely simple example, we solve the linear advection equation
# $$\frac{\partial u}{\partial t} = c \frac{\partial u}{\partial x}$$
# using spectral methods.
#
# For simplicity, we study the equation on the domain
# $$\Omega=[-\pi,\pi]$$
# with periodic boundary conditions.
#
# We represent our function as a sum over positive and negative frequencies of Fourier modes for a total of $2N+1$ modes.
# $$u(t,x) = a_0 + \sum_{k=1}^N\left[ a_k(t) \cos(kx) + b_k(t) \sin(kx) \right]$$
# our vector of coefficients, then, is
# $$\vec{u} = [a_0,a_1,b_1,...,a_N,b_N]$$
#
# We can solve this numerically using the techniques we've learned so far.
#
# Let's get to it. First, let's import our modules.

# %%
# First we import our modules
# %matplotlib inline
import numpy 
from scipy import integrate
from numpy import linalg
import matplotlib.pyplot as plt
from matplotlib import animation
from JSAnimation.IPython_display import display_animation
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.size'] = 16

# %% [markdown]
# Define global constants

# %%
# We define the ORDER of approximation 
N = 7
# And the speed of wave propogation
c = -1
# and the min and max of the domain
xmin = -numpy.pi
xmax = numpy.pi

# %% [markdown]
# For convenience, we define the functional inner product using scipy's integration feature.

# %%
def inner(a,b):
    """
    Compute the inner product of functions a and b on the interval
    """
    return (2.0/(xmax-xmin))*integrate.quad(lambda x: a(x)*b(x),xmin,xmax)[0]

# %% [markdown]
# Define basis functions. We define them as:
# $$\phi_k(x) = \begin{cases}\sqrt{\frac{1}{2}}&\text{if }k = 0\\\cos((k/2)x)&\text{if }k\text{ even}\\\sin((k+1)x/2)&\text{if }k\text{ odd}\end{cases},$$
# where $k/2$ is defined as _integer division_ and always returns the _floor_ of a floating point number.

# %%
# First we define the function analyticially
def phi(k,x):
    k=int(k) #typecast. Be aware this kind of behavior can be dangerous.
    if k == 0:
        # why the ones_like call?
        return numpy.sqrt(1./2)*numpy.ones_like(x)
    elif k % 2 == 0:
        return numpy.cos(int(k/2)*x)
    else:
        return numpy.sin(int(1+k/2)*x)

# %% [markdown]
# Let's plot a few of these:

# %%
x = numpy.linspace(xmin,xmax,100)
[plt.plot(x,phi(k,x)) for k in range(3)]
# Out:
# [[<matplotlib.lines.Line2D at 0x7f9ab7880ad0>],
#  [<matplotlib.lines.Line2D at 0x7f9ab7880d50>],
#  [<matplotlib.lines.Line2D at 0x7f9ab780f450>]]

# %% [markdown]
# Now, assume we have a vector $\vec{u}=[u_0,u_1,...,u_n]$ of Fourier coefficients. How do we extract the $u(x)$? Let's define a function to do it.

# %%
def solution(u):
    """
    Takes a vector u of coefficients u_i and returns the true function
    u(x) = sum(u_i * e^(inx))
    """
    return lambda x: numpy.sum(numpy.array([u[k]*phi(k,x) for k in range(N)]))

# %% [markdown]
# Let's get it over with and define an initial function. We'll use
# $$u0=u(0,x) = \sin(e^{-x^2}).$$
# Let's plot it:

# %%
x = numpy.linspace(xmin,xmax,100)
u_initial = lambda x: numpy.sin(numpy.exp(-x**2))
plt.plot(x,u_initial(x))

# %% [markdown]
# This has the (rather nasty) analytic solution
# $$u(t,x) = \sin(e^{-\text{mod}(t-x,2\pi)^2})+\sin(e^{-\text{mod}(t-x,-2\pi)^2}).$$

# %% [markdown]
# How do we convert this into a spectral representation? Like this!

# %%
def to_modal(u_func):
    """
    Projects a function u_func onto our discrete 
    Fourier basis and returns a vector u
    of Fourier coefficients
    """
    # why the lambda call here?
    return numpy.array([inner(u_func,lambda x: phi(k,x))for k in range(N)])

u0 = to_modal(u_initial)

# %% [markdown]
# Let's see if it looks right.

# %%
plt.plot(x,numpy.vectorize(solution(u0))(x))

# %% [markdown]
# Let's define a derivative operator. What's the best way to do that? We have:
# $$\frac{d\phi_k}{dx} = \begin{cases}0&\text{if }k=0\\-\frac{k}{2}\sin((k/2)x)&\text{if }k\text{ even}\\\frac{k+1}{2}\cos((1+k)x/2)&\text{if }k\text{ odd}\end{cases}$$
# And this is:
# $$\frac{d\phi_k}{dx} = \begin{cases}0&\text{if }k=0\\-\frac{k}{2}\phi_{k-1}&\text{if }k\text{ even}\\\frac{k+1}{2}\phi_{k+1}&\text{if }k\text{ odd}\end{cases}$$

# %%
# Differentiation matrix for the phis
Dphi = numpy.zeros((N,N))
for k in range(1,N-1):
    if k % 2 == 0:
        Dphi[k,k-1] = -k/2
    else:
        Dphi[k,k+1] = 1+k/2
# Differentiation matrix for the u's
D = Dphi.transpose()

# %%
D[1]
# Out:
# array([ 0.,  0., -1.,  0.,  0.,  0.,  0.])

# %%
def rhs(u):
    """
    Given a vector of Fourier coefficeints u, returns du/dt
    """
    return c*numpy.dot(D,u)
    
# For technical reasons, don't use Euler step.
def RK2_step(u,dt):
    """
    Maps u at time t to u at time t + dt, where u is a vector of Fourier coefficients
    """
    u_temp = u + 0.5*dt*rhs(u)
    return u + dt*rhs(u_temp)

# %% [markdown]
# Okay, let's evolve this thing in time.
#
# A word on the CFL condition. Here assume that $\Delta x$ is the wavelength of your smallest mode. In our case, this means that $\Delta x$ should be $\pi/(N)$.

# %%
NUM_T = 100
tmax=2*numpy.pi
t = numpy.linspace(0,tmax,NUM_T)
dt=t[1]-t[0]
u = numpy.empty((len(t),len(u0)))
u[0] = u0 # set initial condition
# Integrate!
for i in range(1,len(t)):
    u[i] = RK2_step(u[i-1],dt)

# %% [markdown]
# Let's animate it!

# %%
fig = plt.figure()
ax = plt.axes(xlim=(xmin,xmax),ylim=(0,1),xlabel=('x'),ylabel=('u'))
line1, = ax.plot([],[],color='#003366', lw=2)
line2, = ax.plot([],[],'r--',lw=2)
def animate(i):
    line1.set_data(x,numpy.vectorize(solution(u[i]))(x))
    line2.set_data(x,numpy.sin(numpy.exp(-((t[i]-x)%(-2*numpy.pi))**2))+numpy.sin(numpy.exp(-((t[i]-x)%(2*numpy.pi))**2)))
    return line1,line2
animation.FuncAnimation(fig, animate, frames=len(t), interval=10)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgFCPVZSSBOYZTSRHU">
#     <br>
#     <input id="_anim_sliderFCPVZSSBOYZTSRHU" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animFCPVZSSBOYZTSRHU.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animFCPVZSSBOYZTSRHU.slower()">&#8211;</button>
#     <button onclick="animFCPVZSSBOYZTSRHU.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFCPVZSSBOYZTSRHU.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFCPVZSSBOYZTSRHU.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFCPVZSSBOYZTSRHU.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animFCPVZSSBOYZTSRHU.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFCPVZSSBOYZTSRHU.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFCPVZSSBOYZTSRHU.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFCPVZSSBOYZTSRHU.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectFCPVZSSBOYZTSRHU" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgFCPVZSSBOYZTSRHU";
#     var slider_id = "_anim_sliderFCPVZSSBOYZTSRHU";
#     var loop_select_id = "_anim_loop_selectFCPVZSSBOYZTSRHU";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6
